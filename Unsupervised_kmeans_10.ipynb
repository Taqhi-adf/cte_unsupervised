# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# Generate 100 random 2D points for a more realistic clustering example
np.random.seed(42)
data = np.random.randint(1, 100, (100, 2))

# Applying K-Means with K=4 (4 clusters for better separation)
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
kmeans.fit(data)

# Get Cluster Labels and Centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot Data Points with Cluster Colors
plt.figure(figsize=(8, 7))
colors = ['blue', 'green', 'purple', 'orange']
for i in range(len(data)):
    plt.scatter(data[i, 0], data[i, 1], c=colors[labels[i]], s=60, edgecolors='black')

# Plot Centroids
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=250, label='Centroids')

# Labels and Legend
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering with 100 Data Points")
plt.legend()
plt.grid()

# Show Plot
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# Generate 1000 random 2D points for a large-scale clustering example
np.random.seed(42)
data = np.random.randint(1, 100, (1000, 2))

# Applying K-Means with K=5 (5 clusters for better separation)
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
kmeans.fit(data)

# Get Cluster Labels and Centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot Data Points with Cluster Colors
plt.figure(figsize=(9, 8))
colors = ['blue', 'green', 'purple', 'orange', 'cyan']
for i in range(len(data)):
    plt.scatter(data[i, 0], data[i, 1], c=colors[labels[i]], s=20, edgecolors='black')

# Plot Centroids
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=300, label='Centroids')

# Labels and Legend
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering with 1000 Data Points")
plt.legend()
plt.grid()

# Show Plot
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Generate 10,000 random 2D points for a large-scale clustering example
np.random.seed(42)
data = np.random.randint(1, 100, (10000, 2))

# Applying K-Means with K=6 (6 clusters for better separation)
kmeans = KMeans(n_clusters=6, random_state=42, n_init=10)
kmeans.fit(data)

# Get Cluster Labels and Centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot Data Points with Cluster Colors
plt.figure(figsize=(10, 9))
colors = ['blue', 'green', 'purple', 'orange', 'cyan', 'magenta']
for i in range(len(data)):
    plt.scatter(data[i, 0], data[i, 1], c=colors[labels[i]], s=10, edgecolors='black')

# Plot Centroids
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=400, label='Centroids')

# Labels and Legend
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering with 10,000 Data Points")
plt.legend()
plt.grid()

# Show Plot
plt.show()

# %%
# Flipkart Customers - Segmentation
# Method: Clustering - K Means
# 1. Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
#2. Generate Customer Data
customers = [ "Aarav", "Vihaan", "Kabir", "Aryan", "Reyansh", "Aditi", "Ishita", "Kiara", "Meera", "Saanvi",
    "Ananya", "Rohan", "Neha", "Dev", "Tanvi", "Krishna", "Riya", "Siddharth", "Pooja", "Aakash"]

df = pd.DataFrame(
    {
        "Customer Name": customers,
        "Age": np.random.randint(18, 65, 20),
        "Annual Income (₹ L)": np.random.randint(3, 50, 20),
        "Spending Score (1-100)": np.random.randint(1, 101, 20)
    }
)
df
#3. Select Features for Clustering
X = df[["Annual Income (₹ L)", "Spending Score (1-100)"]]
X

#4.   Plot - Elbow Method
#    WCSS (Intertia) vs K (1 to 10)
#   Compute WCSS (Within-Cluster Sum of Squares) for k=1 to k=10
wcss = []
for k in range(1, 11): #1, 2, 3, ....10
  kmeans = KMeans(n_clusters = k, random_state = 42)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
  print("For", k, ":", wcss)

Plot WCSS vs K
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--', color = 'b')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS (Inertia)')
plt.title('Elbow Method for Optimal K')
plt.grid(True)
plt.show()

# %%
{"summary":"{\n  \"name\": \"df\",\n  \"rows\": 20,\n  \"fields\": [\n    {\n      \"column\": \"Customer Name\",\n      \"properties\": {\n        \"dtype\": \"string\",\n        \"num_unique_values\": 20,\n        \"samples\": [\n          \"Aarav\",\n          \"Siddharth\",\n          \"Krishna\"\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Age\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 12,\n        \"min\": 19,\n        \"max\": 62,\n        \"num_unique_values\": 19,\n        \"samples\": [\n          39,\n          49,\n          33\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Annual Income (\\u20b9 L)\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 12,\n        \"min\": 3,\n        \"max\": 49,\n        \"num_unique_values\": 19,\n        \"samples\": [\n          43,\n          8,\n          20\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Spending Score (1-100)\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 30,\n        \"min\": 2,\n        \"max\": 96,\n        \"num_unique_values\": 17,\n        \"samples\": [\n          8,\n          42,\n          22\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    }\n  ]\n}","type":"dataframe","variable_name":"df"}
{"summary":"{\n  \"name\": \"X\",\n  \"rows\": 20,\n  \"fields\": [\n    {\n      \"column\": \"Annual Income (\\u20b9 L)\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 12,\n        \"min\": 3,\n        \"max\": 49,\n        \"num_unique_values\": 19,\n        \"samples\": [\n          43,\n          8,\n          20\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Spending Score (1-100)\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 30,\n        \"min\": 2,\n        \"max\": 96,\n        \"num_unique_values\": 17,\n        \"samples\": [\n          8,\n          42,\n          22\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    }\n  ]\n}","type":"dataframe","variable_name":"X"}

# %%
Purpose: wcss (Within-Cluster Sum of Squares) will store the sum of squared distances from each point to the centroid of its assigned cluster.
Why?: This helps us determine the optimal number of clusters (k) using the Elbow Method.

Purpose: Loop through k values from 1 to 10.
Why?: We test different cluster sizes to see how WCSS changes.

n_clusters=k → Specifies the number of clusters.
random_state=42 → Ensures reproducibility (same results every time).
n_init=10 → Runs K-Means 10 times with different centroid seeds and picks the best solution (default behavior in older versions of Scikit-learn).

# %%
#1.	To be covered: After dividing cluster --- identify customers to cluster1.
#2.	Q&A: WCSS and cluster
#3.	Session - Objective:
# Ploting X & Y for 10000 data points (customers 1, 2, 3, ........ --- belong to some features for each):
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Generate random data (10,000 points)
np.random.seed(42)  # for reproducibility
x = np.random.randn(10000)  # normally distributed X values
y = np.random.randn(10000)  # normally distributed Y values

# Step 2: Create a DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Step 3: Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(df['X'], df['Y'], alpha=0.5, s=10, color='blue')
plt.title('Scatter Plot of 10,000 Random Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Generate more dispersed random data (10,000 points)
np.random.seed(42)  # for reproducibility
x = np.random.randn(10000) * 50  # scaled X values
y = np.random.randn(10000) * 50  # scaled Y values

# Step 2: Create a DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Step 3: Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(df['X'], df['Y'], alpha=0.5, s=10, color='green')
plt.title('Scatter Plot of 10,000 Randomly Dispersed Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Generate highly dispersed data
np.random.seed(42)
x = np.random.randn(10000) * 200  # much wider X range
y = np.random.randn(10000) * 200  # much wider Y range

# Step 2: Create DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Step 3: Plot
plt.figure(figsize=(12, 8))
plt.scatter(df['X'], df['Y'], alpha=0.4, s=8, color='purple')
plt.title('Highly Dispersed Scatter Plot of 10,000 Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Generate ultra-dispersed data
np.random.seed(42)
x = np.random.randn(10000) * 1000  # super wide X
y = np.random.randn(10000) * 1000  # super wide Y

# Step 2: DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Step 3: Plot
plt.figure(figsize=(12, 8))
plt.scatter(df['X'], df['Y'], alpha=0.3, s=6, color='crimson')
plt.title('Ultra Dispersed Scatter Plot of 10,000 Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate uniformly spread data between -5000 to +5000
np.random.seed(42)
x = np.random.uniform(-5000, 5000, 10000)
y = np.random.uniform(-5000, 5000, 10000)

# Create DataFrame
df_uniform = pd.DataFrame({'X': x, 'Y': y})

# Plot the data
plt.figure(figsize=(8, 6))
plt.scatter(df_uniform['X'], df_uniform['Y'], alpha=0.5, s=6, color='teal')
plt.title('Uniformly Wide Spread Scatter Plot of 10,000 Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# Reload the original customer data into df
customers = [ "Aarav", "Vihaan", "Kabir", "Aryan", "Reyansh", "Aditi", "Ishita", "Kiara", "Meera", "Saanvi",
    "Ananya", "Rohan", "Neha", "Dev", "Tanvi", "Krishna", "Riya", "Siddharth", "Pooja", "Aakash"]

df = pd.DataFrame(
    {
        "Customer Name": customers,
        "Age": np.random.randint(18, 65, 20),
        "Annual Income (₹ L)": np.random.randint(3, 50, 20),
        "Spending Score (1-100)": np.random.randint(1, 101, 20)
    }
)

# 5. Plot the data of flipkart customers
# Simple Scatter Plot
plt.figure(figsize = (10, 6))
plt.scatter(df["Annual Income (₹ L)"], df["Spending Score (1-100)"], color='blue', alpha=0.7)
plt.title("Income vs Spending Score")
plt.xlabel("Annual Income (₹ L)")
plt.ylabel("Spending Score (1-100)")
plt.grid(True)
plt.show()

# Select Features for Clustering
X = df[["Annual Income (₹ L)", "Spending Score (1-100)"]]


# 6) Apply K-Means Clustering (K=3)
kmeans = KMeans(n_clusters = 3)
df['Cluster'] = kmeans.fit_predict(X)
#help(kmeans.fit_predict)
# {"summary":"{\n  \"name\": \"df\",\n  \"rows\": 20,\n  \"fields\": [\n    {\n      \"column\": \"Customer Name\",\n      \"properties\": {\n        \"dtype\": \"string\",\n        \"num_unique_values\": 20,\n        \"samples\": [\n          \"Aarav\",\n          \"Siddharth\",\n          \"Krishna\"\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Age\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 12,\n        \"min\": 19,\n        \"max\": 62,\n        \"num_unique_values\": 19,\n        \"samples\": [\n          39,\n          49,\n          33\n        ],\n        \"semantic_type\": \"\",\n        \"description\": \"\"\n      }\n    },\n    {\n      \"column\": \"Annual Income (\\u20b9 L)\",\n      \"properties\": {\n        \"dtype\": \"number\",\n        \"std\": 12,\n        \"min\": 3,\n        \"max\": 49,\n        \"num_unique_values\": 19,\n        \"samples\": [\n          43,\n          8,\n          20\n        ],\

# %% [markdown]
# # THE END
